# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("Telco_customer_churn.xlsx")

# %%
df
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# ...

# %%
df.shape
# Out:
# (7043, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %%
df['Churn Label'].value_counts()
# Out:
# Churn Label
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Tenure Months'], bins=30, kde=True)
plt.xlabel('Tenure Months')
plt.ylabel('Customer count')
plt.title('Distribution of Tenure Months vs no of customer')
plt.show()

# %%
df['Tenure Months'].max()
# Out:
# 72

# %%
df['Tenure Months'].min()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Churn Label', y='Tenure Months' , data=df)
plt.xlabel('churn label')
plt.ylabel('tenure month')
plt.title('churn vs tenure month')
plt.show()

# %%
df['Churn Label'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Monthly Charges'], bins=30, kde=True)
plt.xlabel('months charges')
plt.ylabel('Customer count')
plt.title('Distribution of months charges vs no of customer')
plt.show()

# %%
df['Monthly Charges'].max()
# Out:
# 118.75

# %%
df['Monthly Charges'].min()
# Out:
# 18.25

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Churn Label', y='Monthly Charges' , data=df)
plt.xlabel('churn label')
plt.ylabel('month charges')
plt.title('churn vs month charges')
plt.show()

# %%
df[df['Churn Label']=='Yes']['Monthly Charges'].quantile([0.25,0.5,0.75])
# Out:
# 0.25    56.15
# 0.50    79.65
# 0.75    94.20
# Name: Monthly Charges, dtype: float64

# %%
df[df['Churn Label']=='No']['Monthly Charges'].quantile([0.25,0.5,0.75])
# Out:
# 0.25    25.100
# 0.50    64.425
# 0.75    88.400
# Name: Monthly Charges, dtype: float64

# %%
df['Monthly Charges'].describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: Monthly Charges, dtype: float64

# %%
df['Monthly Charges'].quantile([0.25,0.5,0.75])
# Out:
# 0.25    35.50
# 0.50    70.35
# 0.75    89.85
# Name: Monthly Charges, dtype: float64

# %%
df['Contract'].unique()
# Out:
# array(['Month-to-month', 'Two year', 'One year'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Contract', hue='Churn Label', data=df)
plt.xlabel('contract')
plt.ylabel('count')
plt.title('contract vs count')
plt.show()

# %%
df['Internet Service'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Internet Service', hue='Churn Label', data=df)
plt.xlabel('Internet')
plt.ylabel('count')
plt.title('internet vs count')
plt.show()

# %%
df['Payment Method'].unique()
# Out:
# array(['Mailed check', 'Electronic check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Payment Method', hue='Churn Label', data=df)
plt.xlabel('payment')
plt.ylabel('count')
plt.title('payment vs count')
plt.show()

# %%
df['Tech Support'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Tech Support', hue='Churn Label', data=df)
plt.xlabel('Tech support')
plt.ylabel('count')
plt.title('Tech support vs count')
plt.show()

# %%
df['Paperless Billing'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Paperless Billing', hue='Churn Label', data=df)
plt.xlabel('Pa')
plt.ylabel('count')

plt.show()

# %%
avg_tenure=df.groupby("Churn Label")['Tenure Months'].mean()

# %%
avg_tenure
# Out:
# Churn Label
# No     37.569965
# Yes    17.979133
# Name: Tenure Months, dtype: float64

# %%
numerical_cols=['Tenure Months','Monthly Charges','Churn Value','Churn Score','CLTV']
correlation_matrix=df[numerical_cols].corr()

# %%
correlation_matrix
# Out:
#                  Tenure Months  Monthly Charges  Churn Value  Churn Score  \
# Tenure Months         1.000000         0.247900    -0.352229    -0.224987
# Monthly Charges       0.247900         1.000000     0.193356     0.133754
# Churn Value          -0.352229         0.193356     1.000000     0.664897
# Churn Score          -0.224987         0.133754     0.664897     1.000000
# CLTV                  0.396406         0.098693    -0.127463    -0.079782
#
#                      CLTV
# Tenure Months    0.396406
# Monthly Charges  0.098693
# Churn Value     -0.127463
# Churn Score     -0.079782
# CLTV             1.000000

# %%
contract_churn=pd.crosstab(df['Contract'], df['Churn Label'],normalize='index')
contract_churn
# Out:
# Churn Label           No       Yes
# Contract
# Month-to-month  0.572903  0.427097
# One year        0.887305  0.112695
# Two year        0.971681  0.028319

# %%
df['Total Charges'] = pd.to_numeric(df['Total Charges'], errors='coerce')

# %%
df['Total Charges']
# Out:
# 0        108.15
# 1        151.65
# 2        820.50
# 3       3046.05
# 4       5036.30
#          ...
# 7038    1419.40
# 7039    1990.50
# 7040    7362.90
# 7041     346.45
# 7042    6844.50
# Name: Total Charges, Length: 7043, dtype: float64

# %%
df['Total Charges'].isnull().sum()
# Out:
# np.int64(11)

# %%
df[df['Total Charges'].isnull()]['Tenure Months']
# Out:
# 2234    0
# 2438    0
# 2568    0
# 2667    0
# 2856    0
# 4331    0
# 4687    0
# 5104    0
# 5719    0
# 6772    0
# 6840    0
# Name: Tenure Months, dtype: int64

# %%
df[df['Total Charges'].isnull()]['Tenure Months'].shape
# Out:
# (11,)

# %%
df.shape
# Out:
# (7043, 33)

# %%
df['Total Charges']=df['Total Charges'].fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %%
drop_coloumns=[
    'CustomerID','Count','State','Zip Code','Lat Long','Country','Latitude','Longitude','Churn Score','Churn Reason','CLTV'
]

# %%
df=df.drop(columns=drop_coloumns, errors='ignore')

# %%
df.shape
# Out:
# (7043, 22)

# %%
df_encoded=pd.get_dummies(df,drop_first=True)

# %%
df_encoded.head()
# Out:
#    Tenure Months  Monthly Charges  Total Charges  Churn Value  City_Acton  \
# 0              2            53.85         108.15            1       False
# 1              2            70.70         151.65            1       False
# 2              8            99.65         820.50            1       False
# 3             28           104.80        3046.05            1       False
# 4             49           103.70        5036.30            1       False
#
#    City_Adelanto  City_Adin  City_Agoura Hills  City_Aguanga  City_Ahwahnee  \
# 0          False      False              False         False          False
# 1          False      False              False         False          False
# 2          False      False              False         False          False
# 3          False      False              False         False          False
# 4          False      False              False         False          False
#
# ...

# %%
df_encoded
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Value  City_Acton  \
# 0                 2            53.85         108.15            1       False
# 1                 2            70.70         151.65            1       False
# 2                 8            99.65         820.50            1       False
# 3                28           104.80        3046.05            1       False
# 4                49           103.70        5036.30            1       False
# ...             ...              ...            ...          ...         ...
# 7038             72            21.15        1419.40            0       False
# 7039             24            84.80        1990.50            0       False
# 7040             72           103.20        7362.90            0       False
# 7041             11            29.60         346.45            0       False
# 7042             66           105.65        6844.50            0       False
#
# ...

# %%
x = df_encoded.drop(columns=['Churn Value', 'Churn Label_Yes'])
y = df_encoded['Churn Value']

# %%
x.shape
y.shape
print(x)
print(y)
# Out:
#       Tenure Months  Monthly Charges  Total Charges  City_Acton  \
# 0                 2            53.85         108.15       False
# 1                 2            70.70         151.65       False
# 2                 8            99.65         820.50       False
# 3                28           104.80        3046.05       False
# 4                49           103.70        5036.30       False
# ...             ...              ...            ...         ...
# 7038             72            21.15        1419.40       False
# 7039             24            84.80        1990.50       False
# 7040             72           103.20        7362.90       False
# 7041             11            29.60         346.45       False
# 7042             66           105.65        6844.50       False
#
#       City_Adelanto  City_Adin  City_Agoura Hills  City_Aguanga  \
# 0             False      False              False         False
# 1             False      False              False         False
# ...

# %% [markdown]
# Machine Learning Implementation

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# the data will be split into 80%for training and 20% for testing. this split will be random out of 7043, where x train will habe 5634

# %%
X_train.shape
# Out:
# (5634, 1158)

# %%
X_test.shape
# Out:
# (1409, 1158)

# %%
y_train.shape
# Out:
# (5634,)

# %% [markdown]
# Model used will be - Random Forest Classfifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model=RandomForestClassifier(n_estimators=100, random_state=42)

# %%
rf_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred=rf_model.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, recall_score, f1_score, precision_score

# %%
accuracy=accuracy_score(y_test,y_pred)

# %%
print(accuracy)
# Out:
# 0.8048261178140526

# %%
from sklearn.metrics import confusion_matrix

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
print(cm)
# Out:
# [[927  82]
#  [193 207]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87      1009
#            1       0.72      0.52      0.60       400
#
#     accuracy                           0.80      1409
#    macro avg       0.77      0.72      0.74      1409
# weighted avg       0.80      0.80      0.79      1409

# %% [markdown]
# Approach 1- Handle class imbalance

# %%
rf_balanced=RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced')
rf_model.fit(X_train,y_train)
y_pred_balanced=rf_model.predict(X_test)
accuracy_balanced=accuracy_score(y_test,y_pred_balanced)
cm_balanced=confusion_matrix(y_test,y_pred_balanced)
print(cm_balanced)
print(classification_report(y_test,y_pred_balanced))
print(accuracy_balanced)
# Out:
# [[927  82]
#  [193 207]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87      1009
#            1       0.72      0.52      0.60       400
#
#     accuracy                           0.80      1409
#    macro avg       0.77      0.72      0.74      1409
# weighted avg       0.80      0.80      0.79      1409
#
# 0.8048261178140526

# %% [markdown]
# Approach 2 - Hyperparameter tuning. Learn all these n estimator maxed , knn , roc curve ,

# %%
rf_tuned=RandomForestClassifier(n_estimators=500, random_state=42,class_weight='balanced')
rf_tuned.fit(X_train,y_train)
y_pred_tuned=rf_tuned.predict(X_test)
print(classification_report(y_test,y_pred_tuned))
print(accuracy_balanced)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87      1009
#            1       0.71      0.57      0.63       400
#
#     accuracy                           0.81      1409
#    macro avg       0.78      0.74      0.75      1409
# weighted avg       0.81      0.81      0.81      1409
#
# 0.8048261178140526

# %% [markdown]
# ### Hyperparameter Tuning for Random Forest Classifier
#
# Hyperparameter tuning helps to find the optimal set of parameters for a model, which can improve its generalization performance and reduce overfitting. We'll use `GridSearchCV` to systematically search for the best combination of `n_estimators` (number of trees) and `max_depth` (maximum depth of each tree) for our Random Forest model.

# %% [markdown]
# Approach-3 feature importance

# %%
import pandas as pd
feature_importance =pd.DataFrame({
    'features':x.columns,
    'Importance':rf_tuned.feature_importances_
})
feature_importance = feature_importance.sort_values(by='Importance',ascending=False)
print(feature_importance)
# Out:
#                     features    Importance
# 0              Tenure Months  1.060909e-01
# 2              Total Charges  1.042946e-01
# 1            Monthly Charges  8.260581e-02
# 1153       Contract_Two year  4.018621e-02
# 1134          Dependents_Yes  3.653435e-02
# ...                      ...           ...
# 899              City_Sanger  1.783097e-06
# 714          City_Olivehurst  1.572729e-06
# 72    City_Belvedere Tiburon  1.570989e-06
# 83        City_Big Bear Lake  1.198980e-06
# 526               City_Laton  7.064005e-07
#
# [1158 rows x 2 columns]

# %%
print(feature_importance.tail(15))
# Out:
#                    features    Importance
# 188           City_Chilcoot  6.939715e-06
# 45               City_Arvin  6.622422e-06
# 934    City_Shingle Springs  5.835543e-06
# 595           City_Mariposa  5.574473e-06
# 278      City_Duncans Mills  5.158480e-06
# 394            City_Gridley  4.087924e-06
# 281           City_Dunsmuir  3.122964e-06
# 975          City_Stonyford  2.408407e-06
# 418              City_Heber  2.194040e-06
# 954             City_Sonora  2.084433e-06
# 899             City_Sanger  1.783097e-06
# 714         City_Olivehurst  1.572729e-06
# 72   City_Belvedere Tiburon  1.570989e-06
# 83       City_Big Bear Lake  1.198980e-06
# 526              City_Laton  7.064005e-07

# %%
x_selected=x.drop(['Payment Method_Mailed check','Streaming TV_No internet service'],axis=1)

# %%
X_train_sel,X_test_sel,y_train_sel,y_test_sel = train_test_split(x_selected,y,test_size=0.2,random_state=42)

# %%
rf_selected=RandomForestClassifier(n_estimators=300,max_depth=10,random_state=42)
rf_selected.fit(X_train_sel,y_train_sel)
y_pred_selected=rf_selected.predict(X_test_sel)
print(classification_report(y_test_sel,y_pred_selected))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.98      0.86      1009
#            1       0.80      0.25      0.38       400
#
#     accuracy                           0.77      1409
#    macro avg       0.78      0.61      0.62      1409
# weighted avg       0.78      0.77      0.72      1409

# %%
n_estimators_list=[100,200,300,400,500]
max_depth_list=[5,10,15,20]
results=[]
for n_trees in n_estimators_list:
  for depth in max_depth_list:
    rf=RandomForestClassifier(n_estimators=n_trees,max_depth=depth,random_state=42,class_weight='balanced')
    rf.fit(X_train,y_train)
    y_pred=rf.predict(X_test)
    accuracy=accuracy_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    results.append({
        'trees':n_trees,
        'n_estimators':n_trees,
        'max_depth':depth,
        'accuracy':accuracy,
        'recall':recall,
    })
    results_df=pd.DataFrame(results)
    results_df=results_df.sort_values(by=['recall','accuracy'],ascending=False)
    print(results_df)
# Out:
#    trees  n_estimators  max_depth  accuracy  recall
# 0    100           100          5  0.712562  0.8475
#    trees  n_estimators  max_depth  accuracy  recall
# 0    100           100          5  0.712562  0.8475
# 1    100           100         10  0.737402  0.8100
#    trees  n_estimators  max_depth  accuracy  recall
# 0    100           100          5  0.712562  0.8475
# 1    100           100         10  0.737402  0.8100
# 2    100           100         15  0.753016  0.7775
#    trees  n_estimators  max_depth  accuracy  recall
# 0    100           100          5  0.712562  0.8475
# 1    100           100         10  0.737402  0.8100
# 2    100           100         15  0.753016  0.7775
# 3    100           100         20  0.775727  0.7575
#    trees  n_estimators  max_depth  accuracy  recall
# 0    100           100          5  0.712562  0.8475
# 4    200           200          5  0.721079  0.8425
# 1    100           100         10  0.737402  0.8100
# ...

# %%
from sklearn.model_selection import cross_val_score
final_rf=RandomForestClassifier(n_estimators=500,max_depth=10,random_state=42,class_weight='balanced')
scores=cross_val_score(final_rf,x,y,cv=5)

# %%
cv_accuracy=cross_val_score(final_rf,x,y,cv=5)

# %%
cv_accuracy
# Out:
# array([0.76508162, 0.75798439, 0.7310149 , 0.74431818, 0.74715909])

# %%
cv_accuracy.mean()
# Out:
# np.float64(0.7491116362345956)

# %% [markdown]
# OPtional-roc

# %%
from sklearn.metrics import roc_auc_score,roc_curve

# %%
import matplotlib.pyplot as plt

# %%
y_prob=rf_tuned.predict_proba(x)[:,1]
churn_prob=pd.DataFrame({'Churn_Probability':y_prob})

# %%
y_prob_test_set = rf_tuned.predict_proba(X_test)[:,1]
fpr,tpr,thresholds=roc_curve(y_test,y_prob_test_set)
auc_score=roc_auc_score(y_test,y_prob_test_set)
print(auc_score)
# Out:
# 0.8510084241823588

# %% [markdown]
# **Customer Segmentation**

# %%
segmentation_data=pd.DataFrame({
    'Tenure Months':x['Tenure Months'],
    'Monthly Charges':x['Monthly Charges'],
    'Total Charges':x['Total Charges'],
    'Churn Probability':churn_prob['Churn_Probability']
})

# %%
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability
# 0                 2            53.85         108.15              0.784
# 1                 2            70.70         151.65              0.860
# 2                 8            99.65         820.50              0.902
# 3                28           104.80        3046.05              0.752
# 4                49           103.70        5036.30              0.738
# ...             ...              ...            ...                ...
# 7038             72            21.15        1419.40              0.004
# 7039             24            84.80        1990.50              0.020
# 7040             72           103.20        7362.90              0.016
# 7041             11            29.60         346.45              0.106
# 7042             66           105.65        6844.50              0.090
#
# [7043 rows x 4 columns]

# %% [markdown]
# k-Means clustering

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(segmentation_data)

# %%
print(scaled_data[:5])
# Out:
# [[-1.23672422 -0.36266036 -0.9580659   1.58878368]
#  [-1.23672422  0.19736523 -0.93887444  1.82166862]
#  [-0.99240204  1.1595457  -0.64378925  1.9503682 ]
#  [-0.17799476  1.33071079  0.3380854   1.49072686]
#  [ 0.67713287  1.29415125  1.2161497   1.447827  ]]

# %%
from sklearn.cluster import KMeans
wcss=[]
for k in range(1,16):
    kmeans = KMeans(n_clusters=k,random_state=42, n_init=10)
    kmeans.fit(scaled_data)
    wcss.append(kmeans.inertia_)
plt.figure(figsize=(10,5))
plt.plot(range(1,16),wcss,marker='o',linestyle='--')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('Elbow Method')
plt.show()

# %%
kmeans=KMeans(n_clusters=3,random_state=42,n_init=10)
clusters=kmeans.fit_predict(scaled_data)

# %%
segmentation_data['Cluster']=clusters
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability  \
# 0                 2            53.85         108.15              0.784
# 1                 2            70.70         151.65              0.860
# 2                 8            99.65         820.50              0.902
# 3                28           104.80        3046.05              0.752
# 4                49           103.70        5036.30              0.738
# ...             ...              ...            ...                ...
# 7038             72            21.15        1419.40              0.004
# 7039             24            84.80        1990.50              0.020
# 7040             72           103.20        7362.90              0.016
# 7041             11            29.60         346.45              0.106
# 7042             66           105.65        6844.50              0.090
#
#       Cluster
# 0           0
# 1           0
# 2           0
# 3           0
# 4           2
# ...       ...
# ...

# %%
cluster_summary=segmentation_data.groupby('Cluster').mean()

# %%
cluster_summary
# Out:
#          Tenure Months  Monthly Charges  Total Charges  Churn Probability
# Cluster
# 0            11.360724        74.401912     917.828501           0.717540
# 1            27.002420        38.872451     959.176132           0.069325
# 2            57.737698        90.153905    5194.254628           0.126871

# %%
cluster_summary={
    0:'Budget Loyal Customer',
    1:'High Risk New Customer',
    2:'High Value Customer'
}

# %%
segmentation_data['Cluster Segment']=segmentation_data['Cluster'].map(cluster_summary)
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability  \
# 0                 2            53.85         108.15              0.784
# 1                 2            70.70         151.65              0.860
# 2                 8            99.65         820.50              0.902
# 3                28           104.80        3046.05              0.752
# 4                49           103.70        5036.30              0.738
# ...             ...              ...            ...                ...
# 7038             72            21.15        1419.40              0.004
# 7039             24            84.80        1990.50              0.020
# 7040             72           103.20        7362.90              0.016
# 7041             11            29.60         346.45              0.106
# 7042             66           105.65        6844.50              0.090
#
#       Cluster         Cluster Segment
# 0           0   Budget Loyal Customer
# ...

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Tenure Months',y='Churn Probability',hue='Cluster Segment',data=segmentation_data)
# Out:
# <Axes: xlabel='Tenure Months', ylabel='Churn Probability'>

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Total Charges',y='Churn Probability',hue='Cluster Segment',data=segmentation_data,palette='Spectral')
# Out:
# <Axes: xlabel='Total Charges', ylabel='Churn Probability'>

# %% [markdown]
# ### Advanced Hyperparameter Tuning with GridSearchCV for Recall Optimization
#
# Previously, we iterated through a predefined list of `n_estimators` and `max_depth`. To systematically find the best combination of hyperparameters that maximizes recall, we can use `GridSearchCV`. This method performs an exhaustive search over a specified parameter grid, using cross-validation to evaluate each combination.
#
# We'll set `scoring='recall'` to ensure the optimization process prioritizes identifying positive classes correctly.

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold

# Define the parameter grid to search
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Initialize a Random Forest Classifier with balanced class weight
rf_classifier = RandomForestClassifier(random_state=42, class_weight='balanced')

# Set up GridSearchCV
# We use StratifiedKFold to maintain the class distribution in each fold,
# which is crucial for imbalanced datasets.
stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

grid_search = GridSearchCV(
    estimator=rf_classifier,
    param_grid=param_grid,
    scoring='recall', # Optimize for recall
    cv=stratified_kfold,
    n_jobs=-1, # Use all available cores
    verbose=1
)

# Fit GridSearchCV to the training data
grid_search.fit(X_train, y_train)

print(f"Best parameters found: {grid_search.best_params_}")
print(f"Best recall score found: {grid_search.best_score_}")

# Get the best model
best_rf_model = grid_search.best_estimator_

# Make predictions with the best model
y_pred_tuned_grid = best_rf_model.predict(X_test)

# Evaluate the best model
print("\nClassification Report for Best Model (GridSearchCV):\n")
print(classification_report(y_test, y_pred_tuned_grid))
print(f"Accuracy Score: {accuracy_score(y_test, y_pred_tuned_grid)}")
print(f"Recall Score: {recall_score(y_test, y_pred_tuned_grid)}")
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# Best parameters found: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# Best recall score found: 0.8584198184393212
#
# Classification Report for Best Model (GridSearchCV):
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.68      0.78      1009
#            1       0.51      0.84      0.64       400
#
#     accuracy                           0.73      1409
#    macro avg       0.71      0.76      0.71      1409
# weighted avg       0.80      0.73      0.74      1409
#
# Accuracy Score: 0.7288857345635202
# Recall Score: 0.84

# %% [markdown]
# ### Visualizing the ROC Curve
#
# The Receiver Operating Characteristic (ROC) curve is a graphical plot that illustrates the diagnostic ability of a binary classifier system as its discrimination threshold is varied. It plots the True Positive Rate (TPR) against the False Positive Rate (FPR) at various threshold settings. The Area Under the Curve (AUC) is a measure of the model's ability to distinguish between classes.

# %%
from sklearn.metrics import roc_curve, auc

# Get predicted probabilities for the positive class from the best model
y_prob_grid = best_rf_model.predict_proba(X_test)[:, 1]

# Calculate FPR, TPR, and thresholds for the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob_grid)

# Calculate the Area Under the ROC Curve (AUC)
auc_score_grid = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {auc_score_grid:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random Classifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Precision-Recall Curve
#
# For imbalanced datasets, the Precision-Recall curve can often be more informative than the ROC curve. The Precision-Recall curve plots Precision (the proportion of positive identifications that were actually correct) against Recall (the proportion of actual positives that were identified correctly) at various threshold settings. A higher area under the curve (AUC-PR) indicates better performance, especially when one class is significantly smaller than the other.

# %%
from sklearn.metrics import precision_recall_curve, auc

# Calculate precision, recall, and thresholds for the Precision-Recall curve
precision, recall, _ = precision_recall_curve(y_test, y_prob_grid)

# Calculate the Area Under the Precision-Recall Curve (AUC-PR)
auc_pr = auc(recall, precision)

# Plot the Precision-Recall curve
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, color='blue', lw=2, label=f'Precision-Recall curve (AUC = {auc_pr:.2f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='lower left')
plt.grid(True)
plt.show()
